# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

#load the GBPUSD_BID dataset
df = pd.read_csv(r'C:\Users\alexm\FX_project\2024_YTD\GBPUSD_BID_15.06.2024_YTD.csv')
df['Index'] = range(0,168)

# create the variable that will be the time series (close prices)
df_ts = df['Close']

df.head()
# Out:
#                          Local time     Open     High      Low    Close  \
# 0  31.12.2023 22:00:00.000 GMT-0000  1.27292  1.27292  1.27292  1.27292
# 1  01.01.2024 22:00:00.000 GMT-0000  1.27184  1.27596  1.26105  1.26149
# 2  02.01.2024 22:00:00.000 GMT-0000  1.26149  1.26761  1.26139  1.26635
# 3  03.01.2024 22:00:00.000 GMT-0000  1.26629  1.27296  1.26565  1.26808
# 4  04.01.2024 22:00:00.000 GMT-0000  1.26808  1.27707  1.26106  1.27173
#
#         Volume  Index
# 0       0.0000      0
# 1  132314.1907      1
# 2  150505.1010      2
# 3  126626.2498      3
# 4  162841.6604      4

# %%
plt.plot(df['Index'],df['Close'])
plt.ylabel('Date')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
# visualise the full dataset

#load the consolidated dataset
df = pd.read_csv(r'C:\Users\alexm\FX_project\2000_2024\data2.csv')

# remove extra rows and columns
df = df.iloc[200:5383, 0:62]

# reformat Local time variable as a datetime
from datetime import datetime

df['Date'] = df['Date'].str[6:10] +'-'+ df['Date'].str[3:5] +'-'+ df['Date'].str[0:2]
df['Date'] = pd.to_datetime(df['Date'])

print(df.shape)
df.head()
# Out:
# C:\Users\alexm\AppData\Local\Temp\ipykernel_13864\832515181.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\alexm\FX_project\2000_2024\data2.csv')
# (5183, 62)
#           Date   Day  Month    Year  Close_Mid   Volume_Bid   Volume_Ask  \
# 200 2004-02-08   8.0    2.0  2004.0    1.86077  193566.4553  168027.0151
# 201 2004-02-09   9.0    2.0  2004.0    1.86755  185836.2850  161543.9481
# 202 2004-02-10  10.0    2.0  2004.0    1.89076  184724.7819  162177.2662
# 203 2004-02-11  11.0    2.0  2004.0    1.89239  192611.3716  165750.1633
# 204 2004-02-12  12.0    2.0  2004.0    1.88505  186042.9791  161135.5285
#
#       Volume_Tot  Close_Sprd     5D-MA  ...  UK-NomGDP  UK-CPI  UK-Unemp  \
# 200  361593.4704      0.0001  1.842514  ...   323214.0    75.9       4.8
# 201  347380.2331      0.0001  1.848244  ...   323214.0    75.9       4.8
# 202  346902.0481      0.0002  1.860112  ...   323214.0    75.9       4.8
# 203  358361.5349      0.0001  1.871732  ...   323214.0    75.9       4.8
# 204  347178.5076      0.0001  1.879304  ...   323214.0    75.9       4.8
#
#      UK-CorpProf  UK-HshldInc  UK-ResPropInc  UK-SecLend  UK-ConsCred  \
# 200     152273.0     228137.0           48.6        15.3         13.9
# 201     152273.0     228137.0           48.6        15.3         13.9
# 202     152273.0     228137.0           48.6        15.3         13.9
# 203     152273.0     228137.0           48.6        15.3         13.9
# 204     152273.0     228137.0           48.6        15.3         13.9
#
#      UK-RetailVol  UK-MktVol
# 200           8.1       16.6
# 201           8.1       16.6
# 202           8.1       16.6
# 203           8.1       16.6
# 204           8.1       16.6
#
# [5 rows x 62 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

fig, ax = plt.subplots(3, figsize=(8, 12))

ax[0].plot(df['Date'],df['Close_Mid'], color='black')
ax[0].plot(df['Date'],df['50D-MA'], color='red')
ax[0].set(xlabel="Price", ylabel="Date")

ax[1].plot(df['Date'],df['UK-SecLend'])
ax[1].set(xlabel="UK-Secured Lending", ylabel="Date")

ax[2].plot(df['Date'],df['UK-ConsCred'])
ax[2].set(xlabel="UK-Consumer Credit", ylabel="Date")
# Out:
# [Text(0.5, 0, 'UK-Consumer Credit'), Text(0, 0.5, 'Date')]
